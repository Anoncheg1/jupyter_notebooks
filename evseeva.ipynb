# %% [markdown]
# # Линейная корреляция между всеми столбцами

# %% [markdown]
# Значения близкие к +1 и -1 показывают наличие корреляции

# %%
p = 'encoded.pickle'
import seaborn
import matplotlib.pyplot as plt
seaborn.heatmap(df.corr(), annot=True, )
plt.subplots_adjust(right=2, left=0)
plt.show()

# %% [markdown]
# # Нелинейрая корреляция к цели

# %% [markdown]
# ## Зеленая зона выданных кредитов

# %%
from evseeva import feature_importance_forest, get1, get2, get3
p = 'encoded.pickle'
df = get1(p)
feature_importance_forest(df)
# Out:
# Feature ranking:
# (12,)
# 1. Эквифакс 4Score (0.350120)
# 2. Скоринговый балл ОКБ, основной скоринг бюро (0.220303)
# 3. Скоринговый балл НБКИ общ (0.194890)
# 4. ПВ, % (0.140306)
# 5. Анкетный скоринг (0.063046)
# 6. Дата рождения клиента (0.018105)
# 7. Коды системы (0.005299)
# 8. Оценка кредитной истории Эквифакс (0.002869)
# 9. Оценка кредитной истории ОКБ (0.002551)
# 10. Оценка кредитной истории НБКИ (0.001523)
# 11. Решение по заявке (0.000760)
# 12. Системная проверка давшая СФ (0.000228)

# %% [markdown]
# ## Серая зона выданных кредитов

# %%
from evseeva import feature_importance_forest, get1, get2, get3
p = 'encoded.pickle'
df = get2(p)
feature_importance_forest(df)
# Out:
# Feature ranking:
# (12,)
# 1. Скоринговый балл ОКБ, основной скоринг бюро (0.525013)
# 2. Скоринговый балл НБКИ общ (0.225251)
# 3. Эквифакс 4Score (0.067370)
# 4. Анкетный скоринг (0.049798)
# 5. ПВ, % (0.027168)
# 6. Коды системы (0.027010)
# 7. Оценка кредитной истории Эквифакс (0.019732)
# 8. Оценка кредитной истории ОКБ (0.019422)
# 9. Дата рождения клиента (0.019258)
# 10. Оценка кредитной истории НБКИ (0.017292)
# 11. Решение по заявке (0.001608)
# 12. Системная проверка давшая СФ (0.001077)

# %% [markdown]
# ## Красная зона выданных кредитов

# %%
from evseeva import feature_importance_forest, get1, get2, get3
p = 'encoded.pickle'
df = get3(p)
feature_importance_forest(df)
# Out:
# Feature ranking:
# (12,)
# 1. Скоринговый балл ОКБ, основной скоринг бюро (0.425045)
# 2. Скоринговый балл НБКИ общ (0.267233)
# 3. Эквифакс 4Score (0.170948)
# 4. ПВ, % (0.054328)
# 5. Анкетный скоринг (0.033280)
# 6. Дата рождения клиента (0.013486)
# 7. Оценка кредитной истории ОКБ (0.009523)
# 8. Оценка кредитной истории Эквифакс (0.009093)
# 9. Коды системы (0.008572)
# 10. Оценка кредитной истории НБКИ (0.008103)
# 11. Системная проверка давшая СФ (0.000314)
# 12. Решение по заявке (0.000075)

# %% [markdown]
# # Для того чтобы иметь возможность выдать кредиты заявкам из серой зоны мы должны построить модель предсказывающую их и понять ключевые факторы способствующие выявлению таких заявок.

# %% [markdown]
# ## Корреляция комбинаций столбцов для серой и зеленой зоны

# %%
from evseeva import feature_importance_forest, get1, get2, get3
import pandas as pd
p = 'feature_eng.pickle'
df: pd.DataFrame = pd.read_pickle(p)
feature_importance_forest(df, max_depth=2, max_leaf_nodes=10, n_estimators=5)
# Out:
# Feature ranking:
# (210,)
# 1. Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score (0.608420)
# 2. Оценка кредитной истории Эквифакс + Скоринговый балл ОКБ, основной скоринг бюро (0.472856)
# 3. Анкетный скоринг + Скоринговый балл ОКБ, основной скоринг бюро (0.437260)
# 4. Скоринговый балл НБКИ общ + Скоринговый балл ОКБ, основной скоринг бюро (0.407858)
# 5. Коды системы + Скоринговый балл ОКБ, основной скоринг бюро (0.397603)
# 6. Эквифакс 4Score / Скоринговый балл ОКБ, основной скоринг бюро (0.385160)
# 7. Оценка кредитной истории ОКБ + Скоринговый балл ОКБ, основной скоринг бюро (0.380403)
# 8. Решение по заявке + Скоринговый балл ОКБ, основной скоринг бюро (0.371851)
# 9. Скоринговый балл ОКБ, основной скоринг бюро (0.347751)
# 10. ПВ, % + Скоринговый балл ОКБ, основной скоринг бюро (0.347725)

# %% [markdown]
# ## Интерпритация лучшей модели

# %% [markdown]
# Можно предположить, что имеют смысл следующее новое поле:
#
# Оценка кредитной истории Эквифакс + Скоринговый балл ОКБ, основной скоринг бюро + Анкетный скоринг

# %%
import numpy as np
from evseeva import feature_importance_xgboost, get1, get2, get3
p = 'encoded.pickle'
df = get2(p)
df['Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score'] = \
        df['Скоринговый балл ОКБ, основной скоринг бюро'] / df['Эквифакс 4Score']
df.replace([-np.inf], 0, inplace=True)
df.replace([np.inf], 999999999, inplace=True)
df['sum'] = df['Оценка кредитной истории Эквифакс'] + df['Скоринговый балл ОКБ, основной скоринг бюро'] + \
                df['Анкетный скоринг'] + df['Скоринговый балл НБКИ общ']
df.drop('Коды системы', axis=1, inplace=True)
feature_importance_xgboost(df)
# Out:
# 0:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<0.941969752] yes=1,no=2,missing=1
# 	1:[Скоринговый балл НБКИ общ<575] yes=3,no=4,missing=3
# 		3:[Анкетный скоринг<171] yes=7,no=8,missing=7
# 			7:[Дата рождения клиента<24] yes=15,no=16,missing=15
# 				15:leaf=-0.0500000007
# 				16:[Эквифакс 4Score<815] yes=33,no=34,missing=33
# 					33:[Дата рождения клиента<62] yes=63,no=64,missing=63
# 						63:[sum<70] yes=115,no=116,missing=115
# 							115:leaf=-0.342168659
# 							116:leaf=-0.298237056
# 						64:[ПВ, %<34] yes=117,no=118,missing=117
# 							117:leaf=-0.220000014
# 							118:leaf=0.100000001
# 					34:[Скоринговый балл ОКБ, основной скоринг бюро<217] yes=65,no=66,missing=65
# 						65:[Эквифакс 4Score<816] yes=119,no=120,missing=119
# 							119:leaf=0.100000001
# 							120:leaf=-0.229965165
# 						66:[Эквифакс 4Score<821] yes=121,no=122,missing=121
# 							121:leaf=-0.0363636389
# 							122:leaf=-0.325581402
# 			8:[Оценка кредитной истории ОКБ<7] yes=17,no=18,missing=17
# 				17:[Оценка кредитной истории Эквифакс<6] yes=35,no=36,missing=35
# 					35:[Оценка кредитной истории ОКБ<3] yes=67,no=68,missing=67
# 						67:[ПВ, %<48] yes=123,no=124,missing=123
# 							123:leaf=-0.228571445
# 							124:leaf=0.0923076943
# 						68:leaf=-0.289655179
# 					36:[sum<188] yes=69,no=70,missing=69
# 						69:leaf=0.160000011
# 						70:leaf=-0.13333334
# 				18:[ПВ, %<39] yes=37,no=38,missing=37
# 					37:leaf=-0.100000001
# 					38:leaf=0.160000011
# 		4:[Скоринговый балл НБКИ общ<609] yes=9,no=10,missing=9
# 			9:[Оценка кредитной истории ОКБ<7] yes=19,no=20,missing=19
# 				19:[Эквифакс 4Score<736] yes=39,no=40,missing=39
# 					39:[Оценка кредитной истории НБКИ<2] yes=71,no=72,missing=71
# 						71:[Дата рождения клиента<31] yes=127,no=128,missing=127
# 							127:leaf=0.0363636389
# 							128:leaf=-0.187755108
# 						72:leaf=-0.279569894
# 					40:[Скоринговый балл НБКИ общ<589] yes=73,no=74,missing=73
# 						73:[Эквифакс 4Score<813] yes=131,no=132,missing=131
# 							131:leaf=-0.293333352
# 							132:leaf=-0
# 						74:[Эквифакс 4Score<780] yes=133,no=134,missing=133
# 							133:leaf=0.228571445
# 							134:leaf=-0.13333334
# 				20:[Анкетный скоринг<67] yes=41,no=42,missing=41
# 					41:leaf=0.215384632
# 					42:[Скоринговый балл НБКИ общ<580] yes=75,no=76,missing=75
# 						75:leaf=0.109090917
# 						76:[sum<688] yes=135,no=136,missing=135
# 							135:leaf=0.0444444455
# 							136:leaf=-0.209523827
# 			10:[Дата рождения клиента<42] yes=21,no=22,missing=21
# 				21:[Эквифакс 4Score<822] yes=43,no=44,missing=43
# 					43:[Эквифакс 4Score<810] yes=77,no=78,missing=77
# 						77:[Скоринговый балл НБКИ общ<785] yes=137,no=138,missing=137
# 							137:leaf=-0.266127408
# 							138:leaf=-0.218282565
# 						78:[sum<1361] yes=139,no=140,missing=139
# 							139:leaf=-0.0727272779
# 							140:leaf=-0.234482765
# 					44:[sum<805] yes=79,no=80,missing=79
# 						79:[Эквифакс 4Score<850] yes=141,no=142,missing=141
# 							141:leaf=-0.200000003
# 							142:leaf=0.200000003
# 						80:leaf=-0.312727302
# 				22:[Анкетный скоринг<110] yes=45,no=46,missing=45
# 					45:[Анкетный скоринг<81] yes=81,no=82,missing=81
# 						81:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<0.937063694] yes=145,no=146,missing=146
# 							145:leaf=-0.264026403
# 							146:leaf=-0
# 						82:[Дата рождения клиента<66] yes=147,no=148,missing=147
# 							147:leaf=-0.208106309
# 							148:leaf=0.13333334
# 					46:[Дата рождения клиента<48] yes=83,no=84,missing=83
# 						83:[Эквифакс 4Score<583] yes=149,no=150,missing=149
# 							149:leaf=0.0266666692
# 							150:leaf=-0.209999993
# 						84:[Скоринговый балл НБКИ общ<839] yes=151,no=152,missing=151
# 							151:leaf=-0.297352344
# 							152:leaf=-0.0615384653
# 	2:[sum<1586] yes=5,no=6,missing=5
# 		5:[sum<1000] yes=11,no=12,missing=11
# 			11:[Оценка кредитной истории ОКБ<7] yes=23,no=24,missing=23
# 				23:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<1.11451137] yes=47,no=48,missing=48
# 					47:[ПВ, %<51] yes=85,no=86,missing=85
# 						85:[sum<989] yes=153,no=154,missing=153
# 							153:leaf=-0.269151151
# 							154:leaf=-0.109090917
# 						86:leaf=0.0363636389
# 					48:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<1.11630607] yes=87,no=88,missing=88
# 						87:[Анкетный скоринг<84] yes=155,no=156,missing=155
# 							155:leaf=0.160000011
# 							156:leaf=-0.13333334
# 						88:[Анкетный скоринг<66] yes=157,no=158,missing=157
# 							157:leaf=-0.265319884
# 							158:leaf=-0.212445006
# 				24:[Скоринговый балл ОКБ, основной скоринг бюро<731] yes=49,no=50,missing=49
# 					49:[Дата рождения клиента<36] yes=89,no=90,missing=89
# 						89:[sum<739] yes=159,no=160,missing=159
# 							159:leaf=0.117647067
# 							160:leaf=-0.114285722
# 						90:[Скоринговый балл ОКБ, основной скоринг бюро<728] yes=161,no=162,missing=161
# 							161:leaf=-0.16842106
# 							162:leaf=0.200000003
# 					50:[Системная проверка давшая СФ<1] yes=91,no=92,missing=91
# 						91:[Дата рождения клиента<28] yes=163,no=164,missing=163
# 							163:leaf=0.0363636389
# 							164:leaf=-0.246445492
# 						92:[Дата рождения клиента<36] yes=165,no=166,missing=165
# 							165:leaf=-0.200000003
# 							166:leaf=0.0190476198
# 			12:[Анкетный скоринг<81] yes=25,no=26,missing=25
# 				25:[Эквифакс 4Score<788] yes=51,no=52,missing=51
# 					51:[Дата рождения клиента<29] yes=93,no=94,missing=93
# 						93:[Эквифакс 4Score<692] yes=167,no=168,missing=167
# 							167:leaf=-0.164263323
# 							168:leaf=-0.0088888891
# 						94:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<0.943623662] yes=169,no=170,missing=170
# 							169:leaf=0.100000001
# 							170:leaf=-0.213525176
# 					52:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<1.22833848] yes=95,no=96,missing=96
# 						95:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<0.951704502] yes=171,no=172,missing=172
# 							171:leaf=0.13333334
# 							172:leaf=-0.193406597
# 						96:[sum<1186] yes=173,no=174,missing=173
# 							173:leaf=0.0324324332
# 							174:leaf=-0.146341473
# 				26:[Оценка кредитной истории ОКБ<1] yes=53,no=54,missing=53
# 					53:[Дата рождения клиента<63] yes=97,no=98,missing=97
# 						97:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<1.087327] yes=175,no=176,missing=176
# 							175:leaf=-0.282568812
# 							176:leaf=-0.209523827
# 						98:leaf=0.0444444455
# 					54:[Оценка кредитной истории НБКИ<2] yes=99,no=100,missing=99
# 						99:[Эквифакс 4Score<606] yes=177,no=178,missing=177
# 							177:leaf=-0.184946239
# 							178:leaf=-0.118021205
# 						100:[Анкетный скоринг<177] yes=179,no=180,missing=179
# 							179:leaf=-0.1762546
# 							180:leaf=0.105263166
# 		6:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<1.59036326] yes=13,no=14,missing=14
# 			13:[Скоринговый балл ОКБ, основной скоринг бюро<807] yes=27,no=28,missing=27
# 				27:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<1.45185566] yes=55,no=56,missing=56
# 					55:[ПВ, %<5] yes=101,no=102,missing=101
# 						101:[Оценка кредитной истории ОКБ<3] yes=181,no=182,missing=181
# 							181:leaf=-0.109090917
# 							182:leaf=0.15384616
# 						102:[ПВ, %<59] yes=183,no=184,missing=183
# 							183:leaf=-0.189714298
# 							184:leaf=0.109090917
# 					56:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<1.50382233] yes=103,no=104,missing=104
# 						103:leaf=0.171428576
# 						104:leaf=-0.13333334
# 				28:[ПВ, %<11] yes=57,no=58,missing=57
# 					57:[Анкетный скоринг<97] yes=105,no=106,missing=105
# 						105:[Дата рождения клиента<28] yes=189,no=190,missing=189
# 							189:leaf=0.0210526325
# 							190:leaf=-0.12883237
# 						106:[Оценка кредитной истории ОКБ<7] yes=191,no=192,missing=191
# 							191:leaf=-0.0956429318
# 							192:leaf=-0.00975609757
# 					58:[Анкетный скоринг<95] yes=107,no=108,missing=107
# 						107:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<1.29978776] yes=193,no=194,missing=194
# 							193:leaf=-0.142857149
# 							194:leaf=-0.201990053
# 						108:[Эквифакс 4Score<861] yes=195,no=196,missing=195
# 							195:leaf=-0.118790284
# 							196:leaf=-0.181265816
# 			14:[Скоринговый балл ОКБ, основной скоринг бюро<842] yes=29,no=30,missing=29
# 				29:[Анкетный скоринг<94] yes=59,no=60,missing=59
# 					59:leaf=0.171428576
# 					60:leaf=-0.0444444455
# 				30:[ПВ, %<18] yes=61,no=62,missing=61
# 					61:[Дата рождения клиента<64] yes=111,no=112,missing=111
# 						111:[Дата рождения клиента<61] yes=197,no=198,missing=197
# 							197:leaf=-0.210499361
# 							198:leaf=-0.348387092
# 						112:leaf=-0
# 					62:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<2.17197037] yes=113,no=114,missing=114
# 						113:[sum<2394] yes=201,no=202,missing=201
# 							201:leaf=-0.298536599
# 							202:leaf=-0.13333334
# 						114:[Скоринговый балл ОКБ, основной скоринг бюро / Эквифакс 4Score<2.23585677] yes=203,no=204,missing=204
# 							203:leaf=0.109090917
# 							204:leaf=-0.222222239

# %% [markdown]
# Ключевое условие для признания сделки в серой зоне:
#
# sum<952 and ПВ, %<22 and Скоринговый балл НБКИ общ<569 and Эквифакс 4Score>558
#
#
# sum<952 and ПВ, %>60 and Оценка кредитной истории НБКИ>3

# %% [markdown]
# # Проверка sum<952 and ПВ, %<22 and Скоринговый балл НБКИ общ<569 and Эквифакс 4Score>558
